# %% [markdown]
# # Task 5: Mental Health Support Chatbot (Fine-Tuned)
# Train on EmpatheticDialogues and generate supportive responses.

# %%
# Run training once (can be slow on CPU)
# !python train.py

# %%
from chatbot import MentalHealthSupportBot

bot = MentalHealthSupportBot()
print(bot.generate('I feel anxious about my exams and cannot sleep.'))
